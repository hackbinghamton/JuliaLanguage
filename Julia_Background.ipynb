# %% [markdown]
# # Introduction to Julia Language
#
# Julia is a high-level and high-performance programming language that has gained popularity in recent years. It's designed to be as easy to learn as Python while still giving users the speed of C/C++! Right now, it's mainly being used in Data Science and Technical Computing, but many people believe it will overtake Python in the near future.
#
# Here's a bit of background on Julia and what makes it so exceptional.

# %% [markdown]
# ## Who created Julia?
#
# Julia was created in 2009 and officially launched in 2012.
#
# Original creators:
# * Jeff Bezanson
#   * B.S., M.S. in Computer Science
#   * Current CTO of Julia Computing
# * Stefan Karpinski
#   * B.A. in Mathematics
#   * Currently Pursuing a Ph.D. for research modeling local area network traffic
#   * Works for New York University's Center for Data Science as a Research Engineer
# * Viral B. Shah
#   * B.S. in Computer Engineering, Ph.D. in Combinatorial Scientific Computing
#   * Current CEO of Julia Computing
# * Alan Edelman
#   * B.S., M.S., and Ph.D. in Applied Mathematics
#   * Currently a Mathematics Professor at MIT
#
#
# The most important thing to note is that most of them have backgrounds in math or scientific computing. This will come up later.

# %% [markdown]
# ## Why was Julia created?
#
# In the original blog post by Bezanson, Karpinski, Shah, and Edelman, they state the following:
#
# "*In short, because we are greedy.*
#
# *We want a language that's open source, with a liberal license. We want the speed of C with the dynamism of Ruby. We want a language that's homoiconic, with true macros like Lisp, but with obvious, familiar mathematical notation like Matlab. We want something as usable for general programming as Python, as easy for statistics as R, as natural for string processing as Perl, as powerful for linear algebra as Matlab, as good at gluing programs together as the shell. Something that is dirt simple to learn, yet keeps the most serious hackers happy. We want it interactive and we want it compiled.*”
#
# The creators claim it does 90% of the above.
#
# So... does it deliver?

# %% [markdown]
# ### Claim 1: Open Source, with a liberal license.
#
# * Free to download
#   * https://julialang.org/
#
#
# * Open Source, currently with 1200 contributors
#   * https://github.com/JuliaLang/julia
#
#
# * Liberal License
#   * Made available by the MIT License, which means it is freely and perpetually available for:
#     * Private Use
#     * Commercial Use
#     * Modification
#     * Distribution
#
# This claim does hold up!

# %% [markdown]
# ### Claim 2: The Speed of C
#
# The following diagram shows benchmarks of identical, **non-optimized algorithms** normalized so that the speed of the algorithm in C is equal to 1.
#
# For example, the fibonacci sequence is done using the inefficient but common double recursive algorithm.

# %% [markdown]
# ![speeds.PNG](data:image/png;base64,...)

# %% [markdown]
# So, for the most part, this does deliver! While most of the functions are not quite the same speed as C, Julia is much closer to C's speeds than most of the other similar languages, specifically noting JavaScript, MATLAB, Mathematica, Python, and R.

# %% [markdown]
# ### Claim 3: Dynamism of Ruby
#
# Dynamic languages are generally “high-level” languages that perform certain behaviors at runtime rather than at compile time. One common association with dynamic languages is dynamic “typing”.
#
# Python, Ruby, JavaScript, PHP, and Perl are some of the most popular dynamic languages.
#
# Most dynamic languages are interpreted rather than compiled. This is usually what allows for dynamic typing. This includes Python, Ruby, JavaScript, PHP, and Perl (although Perl uses a unique interpreter).
#
# **This is where Julia is unique.** Julia is a compiled language that uses a unique version of **Just-In-Time Compilation**. It only compiles code that is strictly necessary. This allows it to have the dynamism of similar interpreted languages without sacrificing speed.
#
# So ultimately, this does deliver! Julia is also a dynamic language.

# %% [markdown]
# ### Claim 4: Homoiconic, with true macros like Lisp
#
# Homoiconic is usually defined as the following: A program written in this language can be maniuplated as data using this language.
#
# An example of this is what's known as first-class functions, or functions that can be passed as arguments to other functions.
#
# There is some controversy over what counts as a homoiconic language. The vast majority of languages are **able** to be written in such a way that this is true. But most people argue that for a language to be considered homoiconic, it must lend itself to this easily.
#
# Kent Pitman, a programmer hugely involved in the design and implementation of List and many Lisp-based systems, said the following:
#
# “*I like Lisp's willingness to represent itself. People often explain this as its ability to represent itself, but I think that's wrong. **Most languages are capable of representing themselves, but they simply don't have the will to.** Lisp programs are represented by lists and programmers are aware of that. It wouldn't matter if it had been arrays. It does matter that it's program structure that is represented, and not character syntax, but beyond that the choice is pretty arbitrary. It's not important that the representation be the Right® choice. It's just important that it be a common, agreed-upon choice so that there can be a rich community of program-manipulating programs that "do trade" in this common representation.*”
#
# While you can find many passionate arguments going both ways, the general consensus is that Julia is **not** a homoiconic language. While it has the ability to be, writing Julia functions in a homoiconic way requires you to re-imagine the logic of typical Julia code. So unfortunately, this claim does not hold up.

# %% [markdown]
# ### Claim 5: Obvious, familiar mathematical notation like MATLAB
#
# Some pictures are shown below comparing Julia and MATLAB. The consensus is that Julia is either identical notaion to MATLAB (like for matrices) or even closer than MATLAB to traditional written math symbols.

# %% [markdown]
# ![matlab.PNG](data:image/png;base64,...)

# %% [markdown]
# The above pictures both output and display the value 15.
#
# BONUS: Julia allows you to use greek letters as variables such as ϕ (Greek lowercase Phi) and operation symbols such as ≆ (approximately not equal to)
#
# So claim 5 holds up!

# %% [markdown]
# ### Claim 6: As usable for general programming as python
#
# This is a difficult claim to quantify, but let's try.
#
# What makes Python good for "general programming?"
#
# * Easy to learn
#   * simple syntax
#   * don’t have to worry about low-level concepts like memory management
#
# * Libraries for many different things (widely applicable)
#   * Machine learning
#   * Data Science
#   * Mathematics
#   * Image Processing
#   * Signal Processing
#
# * Easy to maintain
#
# * Fast to develop/research with
#
# ALL OF THE ABOVE ARE TRUE FOR JULIA! Therefore, the claim holds up.

# %% [markdown]
# ### Claim 7: As easy for statistics as R
#
# What makes R good for statistics?
#
# * Designed by statisticians for doing statistical analysis
#
# Julia was made my mathematicians for doing mathematics, which included statistical analysis.
#
# * R’s syntax makes it easy to create complex statistical models with just a few lines of code
#
# So does Julia’s.
#
# * Since many statisticians use and contribute to R packages, you’re likely to be able to find support for any statistical analysis you need to perform
#
# While it is true that R is still the default for may statisticians, Julia already has millions of active users, including mathematicians, who contribute and support Julia packages as well
# The most commonly used languages today were not always the default- Julia is growing in popularity and may soon be the default for statistics as well.
#
# Conclusion: This claim holds up... for the most part! (With time, this claim could hold up entirely.)

# %% [markdown]
# ### Claim 8: As natural for string processing as Perl
#
# Perl has a powerful regular expression engine, hence why it is considered natural for string processing.
# Julia has excellent support for RegEx as well.
# It also has the advantage of being compiled vs. interpreted- this helps with speed.
# Some speed benchmarks even put Julia above Perl for String Processing.
#
# Perl also has the disadvantage of being less readable and harder to learn than Julia.
#
# So this claim holds up!

# %% [markdown]
# ### Claim 9: As powerful for linear algebra as MATLAB
#
# Every single linear algebra operation that exists in MATLAB **also exists in Julia**. We will see some of these in the coding portion of the workshop.
#
# Not only do they exist, many of them are faster...

# %% [markdown]
# ![linalg.PNG](data:image/png;base64,...)

# %% [markdown]
# This claim also holds up!

# %% [markdown]
# ### Claim 10: We want it interactive and we want it compiled.
#
# As we went over earlier with the comparison to Ruby, it is both interactive and compiled.
#
# * It is safe to alter Julia source files even after the program has begun to run and compile.
# * Julia uses a modified JIT-compiler
#
# So this final claim also holds up!

# %% [markdown]
# ### Conclusion:
#
# Julia does in fact do nearly everything that the developers set out to do.

# %% [markdown]
# ![final_tally.PNG](data:image/png;base64,...)

# %% [markdown]
# So with that, to learn the basics of Julia, please look at the coding portion of the workshop!
#
# ## “If you are also a greedy, unreasonable, demanding programmer, we want you to give it a try.”
# ### - Jeff Bezanson, Stefan Karpinski, Viral B. Shah, and Alan Edelman
